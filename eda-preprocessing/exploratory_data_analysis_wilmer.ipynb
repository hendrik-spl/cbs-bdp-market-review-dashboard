# %%
# Import necessary libraries
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Modify sys.path for it to contain the main repo path so we can import modules
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from utils.data_utils import get_entire_df

# Load the data
data = get_entire_df()

# Display general information about the dataset
def dataset_overview(df):
    print("\nDataset Overview:")
    print(df.info())
    print("\nSummary Statistics:")
    print(df.describe())
    print("\nMissing Values:")
    print(df.isnull().sum())

dataset_overview(data)
# Out:
# Created dataframe with shape: (3172, 26)
#
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3172 entries, 0 to 3171
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Transaction Name               3172 non-null   object
#  1   Transaction Name URL           3172 non-null   object
#  2   Organization Industries        3128 non-null   object
#  3   Lead Investors                 1557 non-null   object
#  4   Investor Names                 2603 non-null   object
#  5   Money Raised                   2208 non-null   float64
#  6   Money Raised Currency          2219 non-null   object
#  7   Money Raised (in USD)          2208 non-null   float64
#  8   Funding Type                   3172 non-null   object
#  9   Announced Date                 3172 non-null   object
#  10  Pre-Money Valuation            230 non-null    float64
#  11  Pre-Money Valuation Currency   230 non-null    object
#  12  Pre-Money Valuation (in USD)   230 non-null    float64
#  13  Organization Name              3172 non-null   object
#  14  Organization Name URL          3172 non-null   object
#  15  Organization Location          3172 non-null   object
#  16  Organization Description       3172 non-null   object
#  17  Organization Website           3155 non-null   object
#  18  Funding Stage                  3172 non-null   object
#  19  Number of Funding Rounds       3172 non-null   int64
#  20  Total Funding Amount           2515 non-null   float64
#  21  Total Funding Amount Currency  2521 non-null   object
#  22  Total Funding Amount (in USD)  2515 non-null   float64
#  23  Equity Only Funding            3172 non-null   object
#  24  Funding Status                 3113 non-null   object
#  25  Number of Investors            2603 non-null   float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 644.4+ KB
# None
#
# Summary Statistics:
#        Money Raised  Money Raised (in USD)  Pre-Money Valuation  \
# count  2.208000e+03           2.208000e+03         2.300000e+02
# mean   3.386349e+06           2.282553e+06         1.439796e+07
# std    6.679863e+06           3.274520e+06         2.645607e+07
# min    5.000000e+03           4.919000e+03         3.000000e+03
# 25%    4.971438e+05           3.652578e+05         2.325000e+06
# 50%    1.500000e+06           1.285979e+06         5.000000e+06
# 75%    3.700000e+06           3.005368e+06         1.475000e+07
# max    1.000000e+08           6.460000e+07         1.822005e+08
#
#        Pre-Money Valuation (in USD)  Number of Funding Rounds  \
# count                  2.300000e+02               3172.000000
# mean                   6.333074e+06                  2.245271
# std                    8.184364e+06                  1.575312
# min                    2.770000e+02                  1.000000
# 25%                    2.004739e+06                  1.000000
# 50%                    4.093958e+06                  2.000000
# 75%                    7.530418e+06                  3.000000
# max                    7.300000e+07                 17.000000
#
#        Total Funding Amount  Total Funding Amount (in USD)  \
# count          2.515000e+03                   2.515000e+03
# mean           7.184239e+06                   5.662771e+06
# std            2.717932e+07                   1.795429e+07
# min            5.000000e+03                   4.919000e+03
# 25%            7.940690e+05                   6.133980e+05
# 50%            2.400000e+06                   2.054693e+06
# 75%            5.700000e+06                   5.111030e+06
# max            7.065000e+08                   3.759974e+08
#
#        Number of Investors
# count          2603.000000
# mean              3.017288
# std               2.954187
# min               1.000000
# 25%               1.000000
# 50%               2.000000
# 75%               4.000000
# max              35.000000
#
# Missing Values:
# Transaction Name                    0
# Transaction Name URL                0
# Organization Industries            44
# Lead Investors                   1615
# Investor Names                    569
#                                  ...
# Total Funding Amount Currency     651
# Total Funding Amount (in USD)     657
# Equity Only Funding                 0
# Funding Status                     59
# Number of Investors               569
# Length: 26, dtype: int64

# %%
#Check for duplicates
def check_duplicates(df):
    print("\nNumber of Duplicates:", df.duplicated().sum())

check_duplicates(data)
# Out:
# Number of Duplicates: 0

# %%
print(data.head())
# Out:
# <bound method NDFrame.head of                      Transaction Name  \
# 0              Seed Round - Flagright
# 1                Seed Round - aboutuz
# 2             Seed Round - Kubermatic
# 3             Seed Round - MYNE Homes
# 4     Pre Seed Round - Emulate Energy
# ...                               ...
# 3167         Seed Round - Sunmaxx PVT
# 3168         Pre Seed Round - Dema.ai
# 3169         Pre Seed Round - &Hamlet
# 3170            Seed Round - eleQtron
# 3171         Seed Round - AirForestry
#
#                                                             Transaction Name URL  \
# 0              https://www.crunchbase.com/funding_round/flagright-seed--82849d85
# 1                https://www.crunchbase.com/funding_round/aboutuz-seed--9c881e5a
# 2             https://www.crunchbase.com/funding_round/kubermatic-seed--286b6112
# 3             https://www.crunchbase.com/funding_round/myne-homes-seed--3bf4b676
# 4     https://www.crunchbase.com/funding_round/emulate-energy-pre-seed--71a33333
# ...                                                                          ...
# 3167         https://www.crunchbase.com/funding_round/sunmaxx-pvt-seed--a68d23d0
# 3168         https://www.crunchbase.com/funding_round/dema-ai-pre-seed--4b33260f
# 3169     https://www.crunchbase.com/funding_round/hamlet-931a-pre-seed--6ef6184c
# 3170       https://www.crunchbase.com/funding_round/eleqtron-3d70-seed--9836b354
# 3171         https://www.crunchbase.com/funding_round/airforestry-seed--b14d0e26
#
#                                      Lead Investors  Money Raised  \
# 0                                 Moonfire Ventures     2800000.0
# 1                                     FasterCapital      632000.0
# 2                               NetApp Excellerator           0.0
# 3                                               NaN    23500000.0
# 4                                               NaN    21956027.0
# ...                                             ...           ...
# 3167  MAHLE, TGFS - Technologiegründerfonds Sachsen     3250000.0
# 3168                                            J12     4000000.0
# 3169                                            NaN     5875000.0
# 3170                      Earlybird Venture Capital     6500000.0
# 3171                                            NaN    20400000.0
#
#      Money Raised Currency  Money Raised (in USD) Funding Type Announced Date  \
# 0                      USD              2800000.0         Seed     2022-07-07
# 1                      USD               632000.0         Seed     2022-03-01
# 2                      NaN                    0.0         Seed     2022-04-27
# 3                      EUR             23938847.0         Seed     2022-07-08
# 4                      SEK              2092864.0     Pre-Seed     2022-07-15
# ...                    ...                    ...          ...            ...
# 3167                   EUR              3465639.0         Seed     2023-01-07
# 3168                   EUR              4144464.0     Pre-Seed     2022-11-17
# 3169                   NOK               571242.0     Pre-Seed     2023-02-17
# 3170                   EUR              6420203.0         Seed     2022-11-01
# 3171                   SEK              1957420.0         Seed     2023-02-22
#
#       Pre-Money Valuation Pre-Money Valuation Currency  \
# 0                     0.0                          NaN
# 1                     0.0                          NaN
# 2                     0.0                          NaN
# 3                     0.0                          NaN
# 4              63892307.0                          SEK
# ...                   ...                          ...
# 3167                  0.0                          NaN
# 3168                  0.0                          NaN
# 3169           25000000.0                          NOK
# 3170                  0.0                          NaN
# 3171                  0.0                          NaN
#
#       Pre-Money Valuation (in USD) Organization Name  \
# 0                              0.0         Flagright
# 1                              0.0           aboutuz
# 2                              0.0        Kubermatic
# 3                              0.0        MYNE Homes
# 4                        6090260.0    Emulate Energy
# ...                            ...               ...
# 3167                           0.0       Sunmaxx PVT
# 3168                           0.0           Dema.ai
# 3169                     2430819.0           &Hamlet
# 3170                           0.0          eleQtron
# 3171                           0.0       AirForestry
#
#                                        Organization Name URL  \
# 0          https://www.crunchbase.com/organization/flagright
# 1            https://www.crunchbase.com/organization/aboutuz
# 2         https://www.crunchbase.com/organization/kubermatic
# 3         https://www.crunchbase.com/organization/myne-homes
# 4     https://www.crunchbase.com/organization/emulate-energy
# ...                                                      ...
# 3167     https://www.crunchbase.com/organization/sunmaxx-pvt
# 3168         https://www.crunchbase.com/organization/dema-ai
# 3169     https://www.crunchbase.com/organization/hamlet-931a
# 3170   https://www.crunchbase.com/organization/eleqtron-3d70
# 3171     https://www.crunchbase.com/organization/airforestry
#
#                                                                                                                         Organization Description  \
# 0                                                AI-native AML compliance & risk management platform to monitor, screen, investigate, and report
# 1                                aboutuz is the first network for users to safely share personal details (zero-party data) with brands & people.
# 2     Kubermatic empowers organizations worldwide to automate their Kubernetes and cloud native operations across multi-cloud, edge and on-prem.
# 3                                                                         MYNE Homes is a digital co-ownership platform for vacation properties.
# 4        Emulate provides SaaS for utilities to offer behind-the-meter services and optimize demand flexibility with virtual battery technology.
# ...                                                                                                                                          ...
# 3167                                                Sunmaxx PVT designs and develops PVT systems using available and sustainable energy sources.
# 3168                                  The next-gen e-commerce profit analytics platform transforms data into actionable and predictive insights.
# 3169                                  &Hamlet is a protech company that through co-ownership enable more people to own their dream holiday home.
# 3170     eleQtron creates and operates quantum computers based on trapped ions, radio frequency control, and Magnetic Gradient Induced Coupling.
# 3171                                                 #Re-inventing Forestry. We are building the forestry of the future, from above with drones.
#
#                  Organization Website Funding Stage  Number of Funding Rounds  \
# 0               https://flagright.com          Seed                         1
# 1             https://www.aboutuz.com          Seed                         1
# 2          https://www.kubermatic.com          Seed                         3
# 3           https://www.myne-homes.de          Seed                         4
# 4         https://www.emulate.energy/          Seed                         3
# ...                               ...           ...                       ...
# 3167         https://sunmaxx-pvt.com/          Seed                         1
# 3168                 https://dema.ai/          Seed                         2
# 3169            https://andhamlet.com          Seed                         1
# 3170         https://eleqtron.com/en/          Seed                         2
# 3171  https://www.airforestry.com/en/          Seed                         3
#
#       Total Funding Amount Total Funding Amount Currency  \
# 0                2800000.0                           USD
# 1                 632000.0                           USD
# 2                8300000.0                           USD
# 3               63500000.0                           EUR
# 4               56561291.0                           SEK
# ...                    ...                           ...
# 3167             3250000.0                           EUR
# 3168            11000000.0                           EUR
# 3169             5875000.0                           NOK
# 3170            16500000.0                           EUR
# 3171            32000000.0                           SEK
#
#       Total Funding Amount (in USD) Equity Only Funding       Funding Status  \
# 0                         2800000.0                 Yes                 Seed
# 1                          632000.0                 Yes                 Seed
# 2                         8300000.0                 Yes                 Seed
# 3                        67268844.0                 Yes  Early Stage Venture
# 4                         5396545.0                 Yes                 Seed
# ...                             ...                 ...                  ...
# 3167                      3465639.0                 Yes                 Seed
# 3168                     11730402.0                 Yes                 Seed
# 3169                       571242.0                 Yes                 Seed
# 3170                     16297439.0                 Yes                 Seed
# 3171                      3306469.0                 Yes                 Seed
#
#       Number of Investors         City                Region   Country  \
# 0                    11.0       Berlin                Berlin   Germany
# 1                     1.0  Feldkirchen                Bayern   Germany
# 2                     1.0      Hamburg               Hamburg   Germany
# 3                    15.0       Berlin                Berlin   Germany
# 4                     4.0         Lund             Skane Lan    Sweden
# ...                   ...          ...                   ...       ...
# 3167                  2.0      Dresden               Sachsen   Germany
# 3168                  5.0    Stockholm        Stockholms Lan    Sweden
# 3169                  NaN       Bergen             Hordaland    Norway
# 3170                  2.0       Siegen   Nordrhein-Westfalen   Germany
# 3171                  6.0      Uppsala           Uppsala Lan    Sweden
#
#      Continent
# 0       Europe
# 1       Europe
# 2       Europe
# 3       Europe
# 4       Europe
# ...        ...
# 3167    Europe
# 3168    Europe
# 3169    Europe
# 3170    Europe
# 3171    Europe
#
# [3172 rows x 27 columns]>

# %% [markdown]
# ## After a review of the data we can see the follwing:
# 1. "Organization Location" consists of City, Region, Country, Continent in the same sell. This has to be splitted up into separate columns
# 2. "Organization Industries" and "Investor Names" includes many diffirent values in each cell. These has to be splitted up and put in separate tables.
# 3. The following columns contain both numeric values and NaN values. "Money Raised", "Money Raised (in USD)", "Pre-Money Valuation", "Pre-Money Valuation (in USD)", "Total Funding Amount" "Total Funding Amount (in USD)"

# %%
# 1. Split "Organization Location" into "City", "Region", "Country", "Continent"
def split_location_columns(df):
    if 'Organization Location' in df.columns:
        df[['City', 'Region', 'Country', 'Continent']] = df['Organization Location'].str.split(',', expand=True)
        print("\nLocation columns added (City, Region, Country, Continent).")
    else:
        print("\n'Organization Location' column not found.")

split_location_columns(data)

#Drop the original "Organization Location" column
data.drop('Organization Location', axis=1, inplace=True)
# Out:
# Location columns added (City, Region, Country, Continent).

# %%
# 2. Creating separate tables for "Organization Industries" and "Investor Names"

# Split "Organization Industries" into separate rows (normalization)
organization_industries_table = data[['Transaction Name', 'Organization Industries']].copy()
organization_industries_table = organization_industries_table.assign(
    Organization_Industry=organization_industries_table['Organization Industries'].str.split(', ')
).explode('Organization_Industry').drop(columns=['Organization Industries'])

# Split "Investor Names" into separate rows (normalization)
investor_names_table = data[['Transaction Name', 'Investor Names']].copy()
investor_names_table = investor_names_table.assign(
    Investor_Name=investor_names_table['Investor Names'].str.split(', ')
).explode('Investor_Name').drop(columns=['Investor Names'])

# Display the first few rows of the new tables
print("\nOrganization Industries Table:")
print(organization_industries_table.head())
print("\nInvestor Names Table:")
print(investor_names_table.head())
# Out:
# Organization Industries Table:
#          Transaction Name   Organization_Industry
# 0  Seed Round - Flagright              Compliance
# 0  Seed Round - Flagright      Financial Services
# 0  Seed Round - Flagright                 FinTech
# 0  Seed Round - Flagright         Fraud Detection
# 0  Seed Round - Flagright  Information Technology
#
# Investor Names Table:
#          Transaction Name        Investor_Name
# 0  Seed Round - Flagright   Charles Delingpole
# 0  Seed Round - Flagright     Donald Bringmann
# 0  Seed Round - Flagright     Erik Muttersbach
# 0  Seed Round - Flagright  Four Cities Capital
# 0  Seed Round - Flagright    Fredrik Thomassen

# %%
# After creating the new tables, we can drop the original columns from the main DataFrame

def drop_original_columns(df):
    df.drop(columns=['Organization Industries', 'Investor Names'], inplace=True)
    print("\nOriginal columns dropped.")

drop_original_columns(data)
# Out:
# Original columns dropped.

# %%
# 3. Change from NaN to 0 for the numeric columns: "Money Raised", "Money Raised (in USD)", "Pre-Money Valuation", "Pre-Money Valuation (in USD)", "Total Funding Amount" "Total Funding Amount (in USD)"

def fill_na_with_zero(df):
    numeric_columns = ['Money Raised', 'Money Raised (in USD)', 'Pre-Money Valuation', 'Pre-Money Valuation (in USD)', 'Total Funding Amount', 'Total Funding Amount (in USD)']
    df[numeric_columns] = df[numeric_columns].fillna(0)
    print("\nMissing values filled with 0 for numeric columns.")

fill_na_with_zero(data)

#Display the first few rows of the cleaned data focus on the changed columns
print("\nCleaned Data:")
print(data.head())
# Out:
# Missing values filled with 0 for numeric columns.
#
# Cleaned Data:
#                   Transaction Name  \
# 0           Seed Round - Flagright
# 1             Seed Round - aboutuz
# 2          Seed Round - Kubermatic
# 3          Seed Round - MYNE Homes
# 4  Pre Seed Round - Emulate Energy
#
#                                                          Transaction Name URL  \
# 0           https://www.crunchbase.com/funding_round/flagright-seed--82849d85
# 1             https://www.crunchbase.com/funding_round/aboutuz-seed--9c881e5a
# 2          https://www.crunchbase.com/funding_round/kubermatic-seed--286b6112
# 3          https://www.crunchbase.com/funding_round/myne-homes-seed--3bf4b676
# 4  https://www.crunchbase.com/funding_round/emulate-energy-pre-seed--71a33333
#
#         Lead Investors  Money Raised Money Raised Currency  \
# 0    Moonfire Ventures     2800000.0                   USD
# 1        FasterCapital      632000.0                   USD
# 2  NetApp Excellerator           0.0                   NaN
# 3                  NaN    23500000.0                   EUR
# 4                  NaN    21956027.0                   SEK
#
#    Money Raised (in USD) Funding Type Announced Date  Pre-Money Valuation  \
# 0              2800000.0         Seed     2022-07-07                  0.0
# 1               632000.0         Seed     2022-03-01                  0.0
# 2                    0.0         Seed     2022-04-27                  0.0
# 3             23938847.0         Seed     2022-07-08                  0.0
# 4              2092864.0     Pre-Seed     2022-07-15           63892307.0
#
#   Pre-Money Valuation Currency  Pre-Money Valuation (in USD)  \
# 0                          NaN                           0.0
# 1                          NaN                           0.0
# 2                          NaN                           0.0
# 3                          NaN                           0.0
# 4                          SEK                     6090260.0
#
#   Organization Name                                   Organization Name URL  \
# 0         Flagright       https://www.crunchbase.com/organization/flagright
# 1           aboutuz         https://www.crunchbase.com/organization/aboutuz
# 2        Kubermatic      https://www.crunchbase.com/organization/kubermatic
# 3        MYNE Homes      https://www.crunchbase.com/organization/myne-homes
# 4    Emulate Energy  https://www.crunchbase.com/organization/emulate-energy
#
#                                                                                                                      Organization Description  \
# 0                                             AI-native AML compliance & risk management platform to monitor, screen, investigate, and report
# 1                             aboutuz is the first network for users to safely share personal details (zero-party data) with brands & people.
# 2  Kubermatic empowers organizations worldwide to automate their Kubernetes and cloud native operations across multi-cloud, edge and on-prem.
# 3                                                                      MYNE Homes is a digital co-ownership platform for vacation properties.
# 4     Emulate provides SaaS for utilities to offer behind-the-meter services and optimize demand flexibility with virtual battery technology.
#
#           Organization Website Funding Stage  Number of Funding Rounds  \
# 0        https://flagright.com          Seed                         1
# 1      https://www.aboutuz.com          Seed                         1
# 2   https://www.kubermatic.com          Seed                         3
# 3    https://www.myne-homes.de          Seed                         4
# 4  https://www.emulate.energy/          Seed                         3
#
#    Total Funding Amount Total Funding Amount Currency  \
# 0             2800000.0                           USD
# 1              632000.0                           USD
# 2             8300000.0                           USD
# 3            63500000.0                           EUR
# 4            56561291.0                           SEK
#
#    Total Funding Amount (in USD) Equity Only Funding       Funding Status  \
# 0                      2800000.0                 Yes                 Seed
# 1                       632000.0                 Yes                 Seed
# 2                      8300000.0                 Yes                 Seed
# 3                     67268844.0                 Yes  Early Stage Venture
# 4                      5396545.0                 Yes                 Seed
#
#    Number of Investors         City      Region   Country Continent
# 0                 11.0       Berlin      Berlin   Germany    Europe
# 1                  1.0  Feldkirchen      Bayern   Germany    Europe
# 2                  1.0      Hamburg     Hamburg   Germany    Europe
# 3                 15.0       Berlin      Berlin   Germany    Europe
# 4                  4.0         Lund   Skane Lan    Sweden    Europe

# %% [markdown]
# ## Suggestion on Star Schema

# %% [markdown]
# ### FactFunding
# | Column                     | Description                        |
# |----------------------------|------------------------------------|
# | Transaction ID (PK)         | Unique identifier for the transaction |
# | Organization ID (FK)        | Foreign key referencing DimensionOrganization |
# | Lead Investor ID (FK)       | Foreign key referencing DimensionInvestor |
# | Money Raised                | Amount of money raised in local currency |
# | Money Raised (in USD)       | Amount of money raised in USD |
# | Funding Type                | Type of funding (e.g., Seed, Pre-Seed) |
# | Announced Date              | Date when the funding was announced |
# | Funding Stage               | Stage of funding (e.g., Seed, Series A) |
# | Number of Funding Rounds    | Number of funding rounds for the organization |
# | Total Funding Amount        | Total amount of funding raised in local currency |
# | Total Funding Amount (in USD) | Total amount of funding raised in USD |
# | Equity Only                 | Whether it was equity-only funding (Yes/No) |
#
# ---
#
# ### DimensionOrganization
# | Column                     | Description                        |
# |----------------------------|------------------------------------|
# | Organization ID (PK)        | Unique identifier for the organization |
# | Organization Name           | Name of the organization           |
# | City                        | City where the organization is located |
# | Region                      | Region where the organization is located |
# | Country                     | Country where the organization is located |
# | Continent                   | Continent where the organization is located |
# | Organization URL            | URL of the organization's Crunchbase profile |
# | Organization Description     | Brief description of the organization |
# | Organization Website        | Website of the organization        |
#
# ---
#
# ### DimensionInvestor
# | Column                     | Description                        |
# |----------------------------|------------------------------------|
# | Investor ID (PK)            | Unique identifier for the investor |
# | Investor Name               | Name of the investor               |
# | Lead Investor               | Whether the investor is a lead investor (Yes/No) |
# | Transaction ID (FK)         | Foreign key referencing FactFunding |
#
# ---
#
# ### DimensionIndustry
# | Column                     | Description                        |
# |----------------------------|------------------------------------|
# | Industry ID (PK)            | Unique identifier for the industry |
# | Industry Name               | Name of the industry               |
# | Transaction ID (FK)         | Foreign key referencing FactFunding |
